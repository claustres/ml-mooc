# %% [markdown]
# <img src="https://www.digitalvidya.com/wp-content/uploads/2013/05/Digital-Vidya-Website-Logo-HD-2-300x95.png">

# %% [markdown]
# In this assignment you have to develop a game to create a magic square.
# <br> The user will provide input in the form of a number.
# <br> That number would be the size of the square.
# <br> For eg. if the size of the square is 3 then the dimensions of the square would be 3x3 and it will have 9 elements.Also, the elements in the square would be numbers from 1 to 9 in any order.
# <br> The table below shows Magic Square of size 3:
#
# <table style="width:50%">
#    <tr>
#        <td style = "border: 1px solid black;text-align: center;"></td>
#        <td style = "border: 1px solid black;text-align: center;"></td>
#       <td style = "border: 1px solid black;text-align: center;"></td>
#       <td style = "border: 1px solid black;text-align: center;"></td>
#      <td style = "border: 1px solid black;text-align: center;">**Sum of rows**</td>
#    </tr>
#   <tr>
#   <td style = "border: 1px solid black;text-align: center;"></td>
#     <td style = "border: 1px solid black;text-align: center;">2</td>
#     <td style = "border: 1px solid black;text-align: center;">7</td>
#     <td style = "border: 1px solid black;text-align: center;">6</td>
#     <td style = "border: 1px solid black;text-align: center;">**15**</td>
#   </tr>
#   <tr>
#   <td style = "border: 1px solid black;text-align: center;"></td>
#        <td style = "border: 1px solid black;text-align: center;">9</td>
#        <td style = "border: 1px solid black;text-align: center;">5</td>
#        <td style = "border: 1px solid black;text-align: center;">1</td>
#        <td style = "border: 1px solid black;text-align: center;">**15**</td>
#   </tr>
#     <tr>
#        <td style = "border: 1px solid black;text-align: center;"></td>
#        <td style = "border: 1px solid black;text-align: center;">4</td>
#        <td style = "border: 1px solid black;text-align: center;">3</td>
#        <td style = "border: 1px solid black;text-align: center;">8</td>
#        <td style = "border: 1px solid black;text-align: center;">**15**</td>
#    </tr>
#       <tr>
#        <td style = "border: 1px solid black;text-align: center;">**15**</td>
#         <td style = "border: 1px solid black;text-align: center;">**15**</td>
#         <td style = "border: 1px solid black;text-align: center;">**15**</td>
#         <td style = "border: 1px solid black;text-align: center;">**15**</td>
#         <td style = "border: 1px solid black;text-align: center;">**15**</td>
#    </tr>
#
#          <tr>
#        <td style = "border: 1px solid black;text-align: center;"></td>
#         <td style = "border: 1px solid black;text-align: center;colspan='2'">**Sum of columns**</td>
#         <td style = "border: 1px solid black;text-align: center;"></td>
#    </tr>
# </table>
#
#
# A magic square of order $n$ is an arrangement of $n^{2}$ numbers, usually distinct integers, in a square, such that the $n$ numbers in all rows, all columns, and both diagonals sum to the same constant. A magic square contains the integers from 1 to $n^{2}$.
#
# The constant sum in every row, column and diagonal is called the magic constant or magic sum, M. The magic constant of a normal magic square depends only on n and has the following value:
# M = $n$($n^{2}$+1)/2
#
# You don't need to use bruteforce to find each and every combination and check whether the sum of each row, column and diagonal comes out to be same.

# %% [markdown]
# To better understand the algorithm lets continue with above example - Magic Square of size 3
#
# Initially,
#
# <table style="width:25%">
#   <tr>
#     <td style = "border: 1px solid black;text-align: center;">1</td>
#     <td style = "border: 1px solid black;text-align: center;">2</td>
#     <td style = "border: 1px solid black;text-align: center;">3</td>
#   </tr>
#   <tr>
#        <td style = "border: 1px solid black;text-align: center;">4</td>
#        <td style = "border: 1px solid black;text-align: center;">5</td>
#        <td style = "border: 1px solid black;text-align: center;">6</td>
#   </tr>
#     <tr>
#
#        <td style = "border: 1px solid black;text-align: center;">7</td>
#        <td style = "border: 1px solid black;text-align: center;">8</td>
#        <td style = "border: 1px solid black;text-align: center;">9</td>
#       </tr>
# </table>
#
# Follow the algorithm given below to create magic square of any size n.
#
# In any magic square, the first number i.e. 1 is stored at position (n/2, n-1). Let this position be (i,j). The next number is stored at position (i-1, j+1) where we can consider each row & column as circular array i.e. they wrap around.
#
# 1. The position of next number is calculated by decrementing row number of previous number by 1, and incrementing the column number of previous number by 1. At any time, if the calculated row position becomes -1, it will wrap around to n-1. Similarly, if the calculated column position becomes n, it will wrap around to 0.
#
# 2. If the magic square already contains a number at the calculated position, calculated column position will be decremented by 2, and calculated row position will be incremented by 1.
#
# 3. If the calculated row position is -1 & calculated column position is n, the new position would be: (0, n-2).
#
# Steps:
#
# Here, n = 3
#
# 1. position of number 1 = (3/2, 3-1) = (1, 2)
# 2. position of number 2 = (1-1, 2+1) = (0, 0)
# 3. position of number 3 = (0-1, 0+1) = (3-1, 1) = (2, 1)
# 4. position of number 4 = (2-1, 1+1) = (1, 2)
#    Since, at this position, 1 is there. So, apply condition 2.
#    new position=(1+1,2-2)=(2,0)
# 5. position of number 5=(2-1,0+1)=(1,1)
# 6. position of number 6=(1-1,1+1)=(0,2)
# 7. position of number 7 = (0-1, 2+1) = (-1,3) // this is tricky, see condition 3
#    new position = (0, 3-2) = (0,1)
# 8. position of number 8=(0-1,1+1)=(-1,2)=(2,2) //wrap around
# 9. position of number 9=(2-1,2+1)=(1,3)=(1,0) //wrap around
#
#
# <font color=orange>### IMPORTANT NOTE </font>
# <br> **This approach only works when n is odd.**
#
# For reference : http://en.wikipedia.org/wiki/Magic_square

# %%
class Magic_Square_Game:
    '''
    This game class uses two objects - magicsqaure and n.
    Using these two objects you have to use the following 3 methods.
    1. __init__(self,n) 
        init is a constructor. The job of this method is initialization.
    
    2. createRmagicsquare(self)
        This method uses the list magicsquare and the initialised variable n.
        First it will create a magic square of n rows and n columns initialised with 0.
        Later, based on the algorithm provided above it will create a magic square.
    
    3. display(self):
        The job of this method is to display the sum of rows and columns.
        It is upto you how presentable you want to make this method.
        Basic requirement is to display the sum and the final magic square.
    '''
    
    def __init__(self,n):
        '''
        In this constructor you have to create an empty list for the magic square and the a variable n
        Parameters
        ---------
        self - This is the default object passed to a any method of a class
        n - Size of the magic square which will be passed by the user
        '''
        
        self.magicsquare = []
        if n%2 != 0:
            print("Please enter odd value")
        return None
        self.n = n
        
    def createRMagicSquare(self):
        '''
        This method creates magic square of size n with the numbers arranged in such a way that the sum of rows 
        and columns and the diagonals is same i.e (n(n^2+1)/2) 
        Parameters
        ---------
        self - This is the default object passed to a any method of a class
        '''
        
        # Start Code Here
            
        # End Code Here
    
    def validate(self):
        '''
        Validate the magic square: sum of rows and sum of columns
        Parameters
        ---------
        self - This is the default object passed to a any method of a class
        '''
        
        ## START CODE HERE

        ## END CODE HERE
    
    def display(self):
        
        # Print magic square
        print("The Magic Square for n=%d:\nSum of each row or column %d:\n\n"%(self.n, self.n*(self.n*self.n+1)/2))
        
        # Start Code Here

        # End Code Here
            
    @staticmethod        
    def get_sum(list_of_elements):
    
        '''
        A function that computes sum of elements of a list 
        Parameters
        ----------
        list_of_elements : List of elements whose sum is to be computed
        ----------

        Returns
        ----------
        Sum of the elements of the list 
        ----------
        '''
    
        ## START CODE HERE

        ## END CODE HERE
    
    @staticmethod
    def calculateSumofNumbersofaRow(magicsquare,rownumber):
    
        '''
        A function that computes sum of elements of a list along a row
        Parameters
        ----------
        magicsquare : Matrix - Ramanujan Magic Square
        rownumber : Row number along which the sum is to be computed
        ----------

        Returns
        ----------
        Sum of the elements of the list along the row number
        ----------
        '''
        ## START CODE HERE     

        ## END CODE HERE
    
    @staticmethod
    def get_column_elements(magicsquare,columnnumber):
    
        '''
        A function that returns elements of a list along a column
        Parameters
        ----------
        magicsquare : Matrix - Ramanujan Magic Square
        columnnumber : Column number along which the elements are to be fetched
        ----------

        Returns
        ----------
        List elements of the list along the column number
        ----------
        '''
        ## START CODE HERE

        ## END CODE HERE
    
    @staticmethod
    def calculateSumofNumbersofaColumn(magicsquare, columnnumber):
    
        '''
        A function that computes sum of elements of a list along a column
        Parameters
        ----------
        magicsquare : Matrix - Ramanujan Magic Square
        columnnumber : Column number along which the sum is to be computed
        ----------

        Returns
        ----------
        Sum of the elements of the list along the column number
        ----------
        '''
    
        ## START CODE HERE

        ## END CODE HERE

# %%
def gameLauncher():
    i = int(input("Enter the size of magic square, it should be odd  "))
    g = Magic_Square_Game(i)
    g.createRMagicSquare()
    result = g.validate()

    if result == True:
        print("Valid magic square")
        g.display()
    else:
        print("Invalid magic square")

# %%
not_tired = True

while not_tired:
    
    gameLauncher()
    consent = input("Exit Game? Y or N   ")
    
    if consent == 'Y':
        
        not_tired = False

# %% [markdown]
# <table>
#   <tr>
#   <td>**Expected Output:**<td>
#     <td style="text-align:left">Enter the size of magic square5
# <br>Valid magic square
# <br>The Magic Square for n=5:
# <br>Sum of each row or column 65:
# <br>
# <br>  9    3   22   16   15
# <br>  2   21   20   14    8
# <br> 25   19   13    7    1
# <br> 18   12    6    5   24
# <br> 11   10    4   23   17
# <br>Exit Game? Y or N   Y</td>
#   </tr>
# </table>

# %% [markdown]
# # Congratulations
#
# You have completed a small project to develop a game.
# <br> These skills are very very important in software development.
# <br> Good understanding of the concepts learnt in this chapter will really help you a lot when you wear the hat of a developer.
# <br>Buckle up!
# <br>You are doing very well.
# <br>See you in the next chapter.
